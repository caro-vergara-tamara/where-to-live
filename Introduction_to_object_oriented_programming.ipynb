# %% [markdown]
# <a href="https://colab.research.google.com/github/caro-vergara-tamara/where-to-live/blob/main/Introduction_to_object_oriented_programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# State is like attirbutes -> the data itself
#
# Behaviour is equal to methods. --> for example append.
#
#
# Ambas cosas lo tiene una clase.
#
# Para saber que metodos tiene una clase, podemos llamar
#
#
# ```
# dir(nombre_de_la_clase)
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Class es como una funcion general
#
# - Objeto es la evaluacion de esa funcion en un caso particular, por ejemplo la clase puede ser cliente, que tiene la informacion de los clientes y la accion de llamar, un objeto seria esa informacion pero de Maria. *instance*
#
# - State son los valores de un objeto. En el ejemplo anterior, seria el nombre completo de Maria y el numero de celular. *attibutes*
#
# - Behaviour es el acto de llamar. *methods*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can use dir() to list all attributes and methods for an object or class, and then if you need more information on something specific you can use help(), passing, for example, one of the object's methods.
#
#
# Key points covered include:
#
# Objects: They combine data and functionality, embodying both the state (data like a customer's phone number) and behavior (functionality like placing an order) in a single unit.
#
# Classes: These act as blueprints for objects, defining the possible states and behaviors that objects of the class can have. For instance, a Customer class outlines what every customer object will be like.
#
# Attributes and Methods: Attributes represent the data associated with an object (e.g., a DataFrame's .shape), while methods represent the object's functionality (e.g., a DataFrame's .head() method to preview rows).
#
# ou also learned how to identify the class of an object using the type() function and how to explore an object's attributes and methods using the dir() function. For example, to find out the class of a list, you would use:
#
#
# ```
# type([])
# ```
#
#
#
# This lesson laid the foundation for understanding how Python leverages OOP to create reusable and maintainable code by modeling entities as objects with state and behavior.
#
# The goal of the next lesson is to explore how to initialize objects with constructors in Python, allowing for more efficient setting of attributes at the time of object creation.

# %%
# or to create an empty class
class Employee:
  pass

# now playing more and adding more complex things

class Employee:
  def set_name(self, new_name):
    self.name = new_name

  def set_salary(self, new_salary):
    self.salary = new_salary

  # Add a give_raise() method with amount as an argument
  def give_raise(self, amount):
    self.salary = self.salary + amount

# Create the emp object
emp = Employee()
emp.set_name('Korel Rossi')
emp.set_salary(50000)

# Print the salary
print(emp.salary)

# Give emp a raise of 1500
emp.give_raise(1500)
print(emp.salary)

# %% [markdown]
# Constructor
#
# A better strategy would be to add data to the object when creating it, like we do when creating a list or DataFrame. Python allows us to do this by adding a special method to our class called the constructor. The constructor is automatically called every time an object is created. The method has to be called underscore underscore init underscore underscore - the exact name and double underscores are essential for Python to recognize it. Here, we define the init method for the Customer class. The method takes on one argument, name, in addition to the self argument that should be there for any method. In the body of the method, we create the name attribute using self.attribute syntax, assigning its value to the name parameter, and print a message.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Employee:
  # Create __init__() method
  def __init__(self, name, salary = 0):
    # Create the name and salary attributes
    self.name = name
    self.salary = salary

  def give_raise(self, amount):
    self.salary += amount

  def monthly_salary(self):
    return self.salary / 12

emp = Employee("Korel Rossi")
print(emp.name)
print(emp.salary)


# exercise 2

class Employee:
  def __init__(self, name, salary=0):
    self.name = name
    # Check if salary is positive
    if salary > 0:
      self.salary = salary
    else:
      self.salary = 0
      print("Invalid salary!")

  def give_raise(self, amount):
    self.salary += amount

  def monthly_salary(self):
    return self.salary / 12

emp = Employee("Korel Rossi", -1000)
print(emp.name)
print(emp.salary)


# exercise 3
